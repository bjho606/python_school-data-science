# %%
import pandas as pd

xl_file = '/Users/JaehoByun/JB/_School/2021_2 데이터사이언스/과제및시험/score.xlsx'
df = pd.read_excel(xl_file)
# print(df)

midterm20 = df['midterm'] >= 20
final20 = df['final'] >= 20

df2 = df[midterm20 & final20]
print(df2[['sno','midterm','final']])
# Out:
#     sno  midterm  final
# 0     1    35.00  30.10
# 1     2    34.12  30.10
# 2     3    34.30  29.75
# 3     4    31.50  29.05
# 4     5    33.25  21.35
# 5     6    24.50  32.20
# 6     7    23.80  28.70
# 7     8    28.87  25.90
# 8     9    29.75  21.70
# 10   11    29.57  21.35
# 11   12    31.50  20.65
# 12   13    29.75  21.00
# 14   15    28.00  23.10
# 15   16    24.50  24.85
# 18   19    24.50  24.50
# 19   20    28.00  20.65
# 26   27    22.75  22.05
# 28   29    26.25  22.40
# 36   37    24.50  20.30

# %%
# mysql 테이블 생성 및 데이터 추가
import pandas as pd
import pymysql

xl_file = '/Users/JaehoByun/JB/_School/2021_2 데이터사이언스/과제및시험/score.xlsx'
df = pd.read_excel(xl_file)

conn = pymysql.connect(host='localhost', user='root', password='chunjay606', db='data_science')
curs = conn.cursor(pymysql.cursors.DictCursor)

# 테이블 생성
mk_table_sql = """create table if not exists score
    (sno int primary key,
    attendance float,
    homework float,
    discussion int,
    midterm float,
    final float,
    score float,
    grade varchar(3))"""
curs.execute(mk_table_sql)

# 데이터 넣기
insert_sql = """insert into score(sno, attendance, homework, discussion, midterm, final, score, grade)
                values (%s, %s, %s, %s, %s, %s, %s, %s)"""
for idx in range(len(df)):
    curs.execute(insert_sql, tuple(df.values[idx]))
conn.commit()

curs.close()
conn.close()

# %%
# 데이터 삽입 확인
conn = pymysql.connect(host='localhost', user='root', password='chunjay606', db='data_science')
curs = conn.cursor(pymysql.cursors.DictCursor)

show_table_sql = 'select * from score'
curs.execute(show_table_sql)

row = curs.fetchone()
while row:
    print(row)
    row = curs.fetchone()

curs.close()
conn.close()
# Out:
# {'sno': 1, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 35.0, 'final': 30.1, 'score': 92.2, 'grade': 'A'}
# {'sno': 2, 'attendance': 7.73, 'homework': 20.0, 'discussion': 0, 'midterm': 34.12, 'final': 30.1, 'score': 91.95, 'grade': 'A'}
# {'sno': 3, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 34.3, 'final': 29.75, 'score': 91.15, 'grade': 'A'}
# {'sno': 4, 'attendance': 8.0, 'homework': 18.12, 'discussion': 2, 'midterm': 31.5, 'final': 29.05, 'score': 88.67, 'grade': 'A'}
# {'sno': 5, 'attendance': 8.0, 'homework': 20.0, 'discussion': 2, 'midterm': 33.25, 'final': 21.35, 'score': 84.6, 'grade': 'A'}
# {'sno': 6, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 24.5, 'final': 32.2, 'score': 84.07, 'grade': 'A'}
# {'sno': 7, 'attendance': 8.0, 'homework': 19.37, 'discussion': 2, 'midterm': 23.8, 'final': 28.7, 'score': 81.87, 'grade': 'A'}
# {'sno': 8, 'attendance': 8.0, 'homework': 16.87, 'discussion': 0, 'midterm': 28.87, 'final': 25.9, 'score': 79.64, 'grade': 'A'}
# {'sno': 9, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 29.75, 'final': 21.7, 'score': 78.82, 'grade': 'A'}
# {'sno': 10, 'attendance': 7.73, 'homework': 20.0, 'discussion': 0, 'midterm': 31.5, 'final': 19.25, 'score': 78.48, 'grade': 'A'}
# {'sno': 11, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 29.57, 'final': 21.35, 'score': 78.29, 'grade': 'A'}
# {'sno': 12, 'attendance': 6.66, 'homework': 19.37, 'discussion': 0, 'midterm': 31.5, 'final': 20.65, 'score': 78.18, 'grade': 'A'}
# {'sno': 13, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 29.75, 'final': 21.0, 'score': 78.12, 'grade': 'A'}
# {'sno': 14, 'attendance': 8.0, 'homework': 20.0, 'discussion': 0, 'midterm': 31.5, 'final': 18.55, 'score': 78.05, 'grade': 'A'}
# {'sno': 15, 'attendance': 7.73, 'homework': 18.12, 'discussion': 0, 'midterm': 28.0, 'final': 23.1, 'score': 76.95, 'grade': 'A'}
# {'sno': 16, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 24.5, 'final': 24.85, 'score': 76.72, 'grade': 'A'}
# {'sno': 17, 'attendance': 7.46, 'homework': 20.0, 'discussion': 0, 'midterm': 30.62, 'final': 18.55, 'score': 76.63, 'grade': 'A'}
# {'sno': 18, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 30.62, 'final': 18.55, 'score': 76.54, 'grade': 'A'}
# {'sno': 19, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 24.5, 'final': 24.5, 'score': 76.37, 'grade': 'A'}
# {'sno': 20, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 28.0, 'final': 20.65, 'score': 76.02, 'grade': 'A'}
# {'sno': 21, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 35.0, 'final': 12.95, 'score': 75.32, 'grade': 'B'}
# {'sno': 22, 'attendance': 8.0, 'homework': 16.87, 'discussion': 0, 'midterm': 35.0, 'final': 15.05, 'score': 74.92, 'grade': 'B'}
# {'sno': 23, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 29.75, 'final': 17.5, 'score': 74.62, 'grade': 'B'}
# {'sno': 24, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 28.0, 'final': 18.9, 'score': 74.27, 'grade': 'B'}
# {'sno': 25, 'attendance': 7.73, 'homework': 19.37, 'discussion': 2, 'midterm': 35.0, 'final': 10.15, 'score': 74.25, 'grade': 'B'}
# {'sno': 26, 'attendance': 8.0, 'homework': 16.87, 'discussion': 0, 'midterm': 30.45, 'final': 18.9, 'score': 74.22, 'grade': 'B'}
# {'sno': 27, 'attendance': 8.0, 'homework': 19.37, 'discussion': 2, 'midterm': 22.75, 'final': 22.05, 'score': 74.17, 'grade': 'B'}
# {'sno': 28, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 35.0, 'final': 11.9, 'score': 74.0, 'grade': 'B'}
# {'sno': 29, 'attendance': 8.0, 'homework': 16.25, 'discussion': 0, 'midterm': 26.25, 'final': 22.4, 'score': 72.9, 'grade': 'B'}
# {'sno': 30, 'attendance': 8.0, 'homework': 16.87, 'discussion': 0, 'midterm': 28.0, 'final': 19.95, 'score': 72.82, 'grade': 'B'}
# {'sno': 31, 'attendance': 8.0, 'homework': 15.0, 'discussion': 0, 'midterm': 28.87, 'final': 19.95, 'score': 71.82, 'grade': 'B'}
# {'sno': 32, 'attendance': 7.73, 'homework': 20.0, 'discussion': 0, 'midterm': 30.62, 'final': 12.6, 'score': 70.95, 'grade': 'B'}
# {'sno': 33, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 23.45, 'final': 19.95, 'score': 70.77, 'grade': 'B'}
# {'sno': 34, 'attendance': 8.0, 'homework': 20.0, 'discussion': 2, 'midterm': 26.25, 'final': 14.35, 'score': 70.6, 'grade': 'B'}
# {'sno': 35, 'attendance': 8.0, 'homework': 18.12, 'discussion': 0, 'midterm': 28.0, 'final': 16.1, 'score': 70.22, 'grade': 'B'}
# {'sno': 36, 'attendance': 8.0, 'homework': 20.0, 'discussion': 0, 'midterm': 28.0, 'final': 14.0, 'score': 70.0, 'grade': 'B'}
# {'sno': 37, 'attendance': 8.0, 'homework': 16.87, 'discussion': 0, 'midterm': 24.5, 'final': 20.3, 'score': 69.67, 'grade': 'B'}
# {'sno': 38, 'attendance': 7.73, 'homework': 20.0, 'discussion': 0, 'midterm': 25.37, 'final': 16.45, 'score': 69.55, 'grade': 'B'}
# {'sno': 39, 'attendance': 8.0, 'homework': 13.75, 'discussion': 0, 'midterm': 33.25, 'final': 14.35, 'score': 69.35, 'grade': 'B'}
# {'sno': 40, 'attendance': 8.0, 'homework': 20.0, 'discussion': 2, 'midterm': 24.5, 'final': 14.7, 'score': 69.2, 'grade': 'B'}
# {'sno': 41, 'attendance': 7.46, 'homework': 19.37, 'discussion': 0, 'midterm': 24.5, 'final': 17.85, 'score': 69.18, 'grade': 'C'}
# {'sno': 42, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 22.75, 'final': 18.55, 'score': 68.67, 'grade': 'C'}
# {'sno': 43, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 22.57, 'final': 18.9, 'score': 68.57, 'grade': 'C'}
# {'sno': 44, 'attendance': 8.0, 'homework': 17.5, 'discussion': 0, 'midterm': 29.75, 'final': 13.3, 'score': 68.55, 'grade': 'C'}
# {'sno': 45, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 30.62, 'final': 10.15, 'score': 68.14, 'grade': 'C'}
# {'sno': 46, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 24.5, 'final': 15.75, 'score': 67.62, 'grade': 'C'}
# {'sno': 47, 'attendance': 8.0, 'homework': 20.0, 'discussion': 0, 'midterm': 29.75, 'final': 9.8, 'score': 67.55, 'grade': 'C'}
# {'sno': 48, 'attendance': 8.0, 'homework': 16.87, 'discussion': 0, 'midterm': 19.25, 'final': 21.35, 'score': 65.47, 'grade': 'C'}
# {'sno': 49, 'attendance': 7.73, 'homework': 16.87, 'discussion': 0, 'midterm': 27.82, 'final': 12.25, 'score': 64.67, 'grade': 'C'}
# {'sno': 50, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 25.37, 'final': 11.9, 'score': 64.64, 'grade': 'C'}
# {'sno': 51, 'attendance': 7.46, 'homework': 18.75, 'discussion': 0, 'midterm': 33.25, 'final': 4.55, 'score': 64.01, 'grade': 'C'}
# {'sno': 52, 'attendance': 7.73, 'homework': 17.5, 'discussion': 2, 'midterm': 22.75, 'final': 14.0, 'score': 63.98, 'grade': 'C'}
# {'sno': 53, 'attendance': 7.73, 'homework': 15.62, 'discussion': 0, 'midterm': 21.0, 'final': 19.25, 'score': 63.6, 'grade': 'C'}
# {'sno': 54, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 24.5, 'final': 11.2, 'score': 63.07, 'grade': 'C'}
# {'sno': 55, 'attendance': 7.2, 'homework': 17.5, 'discussion': 0, 'midterm': 18.37, 'final': 19.6, 'score': 62.67, 'grade': 'C'}
# {'sno': 56, 'attendance': 7.73, 'homework': 20.0, 'discussion': 0, 'midterm': 19.25, 'final': 14.7, 'score': 61.68, 'grade': 'C'}
# {'sno': 57, 'attendance': 7.46, 'homework': 16.87, 'discussion': 0, 'midterm': 26.25, 'final': 10.85, 'score': 61.43, 'grade': 'C'}
# {'sno': 58, 'attendance': 8.0, 'homework': 20.0, 'discussion': 0, 'midterm': 28.87, 'final': 4.55, 'score': 61.42, 'grade': 'C'}
# {'sno': 59, 'attendance': 7.46, 'homework': 17.5, 'discussion': 0, 'midterm': 23.8, 'final': 12.6, 'score': 61.36, 'grade': 'C'}
# {'sno': 60, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 26.25, 'final': 7.7, 'score': 61.32, 'grade': 'C'}
# {'sno': 61, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 21.0, 'final': 12.25, 'score': 60.35, 'grade': 'D'}
# {'sno': 62, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 21.0, 'final': 11.9, 'score': 60.27, 'grade': 'D'}
# {'sno': 63, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 21.17, 'final': 11.9, 'score': 60.17, 'grade': 'D'}
# {'sno': 64, 'attendance': 7.73, 'homework': 20.0, 'discussion': 0, 'midterm': 24.5, 'final': 7.35, 'score': 59.58, 'grade': 'D'}
# {'sno': 65, 'attendance': 8.0, 'homework': 16.87, 'discussion': 0, 'midterm': 21.7, 'final': 12.25, 'score': 58.82, 'grade': 'D'}
# {'sno': 66, 'attendance': 7.73, 'homework': 19.37, 'discussion': 2, 'midterm': 21.87, 'final': 7.35, 'score': 58.32, 'grade': 'D'}
# {'sno': 67, 'attendance': 7.46, 'homework': 19.37, 'discussion': 0, 'midterm': 15.75, 'final': 14.35, 'score': 56.93, 'grade': 'D'}
# {'sno': 68, 'attendance': 7.46, 'homework': 19.37, 'discussion': 0, 'midterm': 17.5, 'final': 11.2, 'score': 55.53, 'grade': 'D'}
# {'sno': 69, 'attendance': 8.0, 'homework': 19.37, 'discussion': 2, 'midterm': 14.87, 'final': 11.2, 'score': 55.44, 'grade': 'D'}
# {'sno': 70, 'attendance': 7.73, 'homework': 16.87, 'discussion': 0, 'midterm': 21.0, 'final': 9.8, 'score': 55.4, 'grade': 'D'}
# {'sno': 71, 'attendance': 8.0, 'homework': 16.87, 'discussion': 0, 'midterm': 15.75, 'final': 13.3, 'score': 53.92, 'grade': 'D'}
# {'sno': 72, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 19.25, 'final': 7.35, 'score': 53.7, 'grade': 'D'}
# {'sno': 73, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 24.5, 'final': 1.05, 'score': 52.65, 'grade': 'D'}
# {'sno': 74, 'attendance': 8.0, 'homework': 19.37, 'discussion': 2, 'midterm': 22.75, 'final': 0.0, 'score': 52.12, 'grade': 'D'}
# {'sno': 75, 'attendance': 8.0, 'homework': 16.25, 'discussion': 0, 'midterm': 24.5, 'final': 2.8, 'score': 51.55, 'grade': 'D'}
# {'sno': 76, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 12.25, 'final': 11.9, 'score': 51.52, 'grade': 'D'}
# {'sno': 77, 'attendance': 7.73, 'homework': 15.62, 'discussion': 0, 'midterm': 16.62, 'final': 8.05, 'score': 48.02, 'grade': 'D'}
# {'sno': 78, 'attendance': 8.0, 'homework': 15.0, 'discussion': 0, 'midterm': 15.05, 'final': 9.45, 'score': 47.5, 'grade': 'D'}
# {'sno': 79, 'attendance': 7.73, 'homework': 16.87, 'discussion': 0, 'midterm': 11.9, 'final': 10.5, 'score': 47.0, 'grade': 'D'}
# {'sno': 80, 'attendance': 6.66, 'homework': 16.87, 'discussion': 0, 'midterm': 22.05, 'final': 1.4, 'score': 46.98, 'grade': 'D'}
# {'sno': 81, 'attendance': 7.73, 'homework': 18.12, 'discussion': 0, 'midterm': 10.5, 'final': 10.15, 'score': 46.5, 'grade': 'F'}
# {'sno': 82, 'attendance': 7.73, 'homework': 20.0, 'discussion': 0, 'midterm': 12.95, 'final': 5.25, 'score': 45.93, 'grade': 'F'}
# {'sno': 83, 'attendance': 7.73, 'homework': 19.37, 'discussion': 0, 'midterm': 13.12, 'final': 5.6, 'score': 45.82, 'grade': 'F'}
# {'sno': 84, 'attendance': 7.73, 'homework': 18.75, 'discussion': 0, 'midterm': 17.5, 'final': 1.05, 'score': 45.03, 'grade': 'F'}
# {'sno': 85, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 14.0, 'final': 2.45, 'score': 43.82, 'grade': 'F'}
# {'sno': 86, 'attendance': 8.0, 'homework': 18.75, 'discussion': 0, 'midterm': 6.12, 'final': 10.15, 'score': 43.02, 'grade': 'F'}
# {'sno': 87, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 11.37, 'final': 2.1, 'score': 40.84, 'grade': 'F'}
# {'sno': 88, 'attendance': 8.0, 'homework': 20.0, 'discussion': 0, 'midterm': 9.62, 'final': 2.8, 'score': 40.42, 'grade': 'F'}
# {'sno': 89, 'attendance': 8.0, 'homework': 19.37, 'discussion': 0, 'midterm': 6.12, 'final': 4.55, 'score': 38.04, 'grade': 'F'}
# {'sno': 90, 'attendance': 7.73, 'homework': 18.75, 'discussion': 0, 'midterm': 3.5, 'final': 0.0, 'score': 29.98, 'grade': 'F'}
# {'sno': 91, 'attendance': 7.2, 'homework': 0.0, 'discussion': 0, 'midterm': 3.5, 'final': 1.05, 'score': 11.75, 'grade': 'F'}
# {'sno': 92, 'attendance': 5.6, 'homework': 5.0, 'discussion': 0, 'midterm': 0.0, 'final': 0.0, 'score': 10.6, 'grade': 'F'}

# %%
import pymysql
conn = pymysql.connect(host='localhost', user='root', password='chunjay606', db='data_science')
curs = conn.cursor(pymysql.cursors.DictCursor)

sql = """select sno, midterm, final 
        from score 
        where midterm >= 20 and final >= 20
        order by sno"""
curs.execute(sql)

row = curs.fetchone()
while row:
    print(row)
    row = curs.fetchone()

curs.close()
conn.close()
# Out:
# {'sno': 1, 'midterm': 35.0, 'final': 30.1}
# {'sno': 2, 'midterm': 34.12, 'final': 30.1}
# {'sno': 3, 'midterm': 34.3, 'final': 29.75}
# {'sno': 4, 'midterm': 31.5, 'final': 29.05}
# {'sno': 5, 'midterm': 33.25, 'final': 21.35}
# {'sno': 6, 'midterm': 24.5, 'final': 32.2}
# {'sno': 7, 'midterm': 23.8, 'final': 28.7}
# {'sno': 8, 'midterm': 28.87, 'final': 25.9}
# {'sno': 9, 'midterm': 29.75, 'final': 21.7}
# {'sno': 11, 'midterm': 29.57, 'final': 21.35}
# {'sno': 12, 'midterm': 31.5, 'final': 20.65}
# {'sno': 13, 'midterm': 29.75, 'final': 21.0}
# {'sno': 15, 'midterm': 28.0, 'final': 23.1}
# {'sno': 16, 'midterm': 24.5, 'final': 24.85}
# {'sno': 19, 'midterm': 24.5, 'final': 24.5}
# {'sno': 20, 'midterm': 28.0, 'final': 20.65}
# {'sno': 27, 'midterm': 22.75, 'final': 22.05}
# {'sno': 29, 'midterm': 26.25, 'final': 22.4}
# {'sno': 37, 'midterm': 24.5, 'final': 20.3}
